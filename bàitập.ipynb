# %%
import pandas as pd
import numpy as np

# 3 file CSV nằm cùng thư mục với notebook
tep_info = 'sensor_info.csv'
tep_readings = 'sensor_readings.csv'
tep_maint = 'maintenance_log.csv'

# %%
df_thong_tin = pd.read_csv(tep_info)
df_doc_cam_bien = pd.read_csv(tep_readings)
df_bao_tri = pd.read_csv(tep_maint)

print('=== sensor_info ===')
print(df_thong_tin.head())
print('\n=== sensor_readings ===')
print(df_doc_cam_bien.head())
print('\n=== maintenance_log ===')
print(df_bao_tri.head())
# Out:
# === sensor_info ===
#   sensor_id machine_id location  sensor_type
# 0     SEN01       MC01    Line1      Current
# 1    SEN02        MC04    Line1  Temperature
# 2     sen03       MC04    khu a    Vibration
# 3    SEN04        MC05    Line1    Vibration
# 4    SEN05        MC05    khu a    Vibration
#
# === sensor_readings ===
#   sensor_id         timestamp   value  unit
# 0    SEN08   2024-01-08 12:23      -5    °C
# 1     sen03  08/01/2024 18:46    80.0   Amp
# 2     SEN09  01/01/2024 20:33    25.5  mm/s
# 3    SEN08   07/01/2024 17:47   45.0     °C
# 4     SEN09  2024-01-09 12:37    25.5     A
#
# === maintenance_log ===
#   machine_id maintenance_date issue_type downtime_hours
# 0       MC04       05/02/2024  over heat            1.5
# 1       MC01       2024-01-10    elect              NaN
# 2       MC04       08/01/2024  Vibration             3h
# 3       MC02       01/02/2024    elect              2.0
# 4       MC01       08/01/2024       vib             1.5
